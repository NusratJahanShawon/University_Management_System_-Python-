# %%
# "University Management system"

#University Information
university_info=[['Name: Independent University, Bangladesh'],
                 ['Address: Plot 16 Aftab Uddin Ahmed Rd, Dhaka 1229'],
                 ['Vice-chancellor: Tanweer Hasan'],
                 ['Founded: 1993'],
                 ['Students: More than 7,500 undergraduate and graduate students'],
                 ['Phone: 09612-939393']]

def University_info():
  print("----------UNIVERSITY INFROMATIONS----------")
  for row in university_info:
    for c in row:
       print(c,end=' ')
     
    print()

#University faculty Information 
#Facultys 
Faculty=[["01.","Business and Entrepreneurship.","School_code=101"],
         ["02.","Engineering, Techonology and Science.","School_code=102"],
         ["03.","Environment and Life Science.","School_code=103"],
         ["04.","Liberal Arts & Social Science.","School_code=104"],
         ["05.","Pharmacy and Public Health.","School_code=105"]]

def All_Faculty(Faculty):
  print("------We have those Facultys in our University------")
  print("\n")
  for row in Faculty:
    for c in row:
      print(c,end=" ")

    print()

#Depertments we have
Depertments_info={
              1000: dict(Name="Accounting" , School=101 ),
              1001: dict(name="Finance" , School=101   ),
              1002: dict(name="General Management", School=101),
              1003: dict(name="Human Resource Management (HRM)", School=101),
              1004: dict( name="Marketing" , School=101),
              1005: dict(name="Management Information System (MIS)" , School=101),
              1006: dict(name="International Business", School=101),
              1007: dict(name="Economics", School=101),
              1008: dict(name="Computer Engineering", School=102),
              1009: dict(name="Computer Science",School=102),
              1010: dict(name="Computer Science & Engineering", School=102),
              1011: dict(name="Electrical & Electronic Engineering", School=102),
              1012: dict(name="Electronic & Telecommunication Engineering", School=102),
              1013: dict(name="Mathematics", School=102),
              1014: dict(name="Physics", School=102),
              1015: dict(name="Environmental Science and Management", School=103),
              1016: dict(name="Microbiology", School=103),
              1017: dict(name="Biochemistry and Biotechnology", School=103),
              1018: dict(name="Media & Communication", School=104),
              1020: dict(name="Sociology", School=104),
              1021: dict(name="Anthropology", School=104),
              1022: dict(name="Global Studies and Governance (GSG)", School=104),
              1023: dict(name="LLB(Hons)", School=104),
              1024: dict(name="English Literature" ,School=104),
              1025: dict(name="English Language Teaching (ELT)" ,School=104),   
              1026: dict(name="Bachelor of Pharmacy (BPharm)",School=105 )
                                  }
def get_Depertment_data():
  print("Our Depertment codes are from 1000-1026")
  faculty_id=int(input("Enter the Depertment Code---"))
  print("-----------------------------")
  if faculty_id in Depertments_info:
    print(Depertments_info[faculty_id])
    return
  else:
    print(faculty_id, "Subject Dosn't Exists")
    return


#Admission Information
Admission_information= [['01:Admition_Type=Undergraduate'],['Semester= Spring 2020'], ['start-deadline= ongoing - 30th December2021'],
                        ['--------------------------------------'],
                        ['02:MBS-EMBA'],['Semester= Two Years Program'],['Start-Deadline="Ongoing-16th December']]
                                                
def Admission_info():
  print("--------ADMISSION INFORMATIONS---------")
  for row in Admission_information:
    for c in row:
      print(c,end=' ')
    print()

def Apply_for_Admission():
  print("--------APPLY TODAY-------")
  print("Follow the steps")
  print("Go visit our Webside ---- www.iub.edu.bd ---- **THANK YOU**")


#Student Informations
Student_information=[['01.', 'Around 2500' ,'in', 'school=Business and Entrepreneurship'],
                     ['02.', 'Around 3500' ,'in', 'school=Engineering, Techonology and Science'],
                     ['03.', 'Around 1000' ,'in', 'school=Environment and Life Science'],
                     ['04.', 'Around 800'  ,'in', 'school=Liberal Arts & Social Science'],
                     ['05.', 'Around 250'  ,'in', 'school=Pharmacy and Public Health']]

def Total_students():
  print("-------------------TOTAL STUDENTS-----------------------")
  for row in Student_information:
    for c in row:
      print(c, end=' ')
    print()                     


# libary information
Books_list=[["01.","Business and Entrepreneurship_books.","shelff number-1A-8F-","floor-1st"],
            ["02.","Engineering, Techonology and Science.","shelf number-2A-2F-","floor-2nd"],
            ["03.","Environment and Life Science.","shelf number-3A-3F-","floor-3rd"],
            ["04.","Liberal Arts & Social Science_books.","shelf number-4A-4F-","floor-4th"],
            ["05.","Pharmacy and Public Health_books.","shelf number-5A-5C-","floor-5th"],
            ["06.","Other sectorts books.","shelf number-5D-5F-","floor-5th"]
              ]

def Display_Books_info():
  print("-------------------LIBARY  INFORMATION---------------------")             
  for r in Books_list:
    for c in r :
      print(c, end=" ")
    print()
  print("\n") 


def Borrow_book():
  Your_taken_book_profile=[]
  print('--------------Book Borrwing Process-------------------')
  A=int(input("If you want to borrow a book press-1,if you don't press 0------"))
  while A != 0:
    print("---Give us the books details you want to borrow---")
    Book_Name=input("Book name:")
    Time_Need=(input("How many days you want to keep?"))   
    All_info=[Book_Name,Time_Need]
    Your_taken_book_profile.append(All_info)
    print("\n")
    print("You can print your borrowed book list by pressing-0")
    A=int(input("If You want to go back to the process press-1"))    
    if A==0:
      print("\n")
      print("-----------BOOKS YOU BORROWED--------------")  
      print(Your_taken_book_profile)
      break 
        
      


#Grading System
Grades=[["01.","A=4.00","Comment:","excellent"],
        ["02.","A-=3.75","Comment:","Great"],
        ["03.","B+=3.50","Comment:","very good"],
        ["04.","B=3.25","Comment:","good"],
        ["05.","B-=3.00","Comment:","not Bad"]]

def Grading_info():
  print("-------------OUR GRADING SYSTEMS-------------") 
  for r in Grades:
    for c in r:
      print(c,end=" ")
    print()
    
def Add_grading():
  print("-----------ADD NEW GRADEING ---------------")
  No=(input("Enter the serial number:"))
  Grade=input("Enter the new grade:")
  Comments=input("You can enter any comments:")
  New_Grading=[No, Grade, Comments]
  Grades.append(New_Grading)
  for r in Grades:
    for c in r:
      print(c,end=" ")
    print()

def delete_Grading():
  print("-----------DELETE ANY GRADING-----------")
  print("Enter the appropriate index number of the gread file")
  index_no=int(input('Enter the No--'))
  Grades.remove(Grades[index_no])
  print("\n")
  print("---------NOW GRADE LIST--------")  
  for r in Grades:
    for c in r:
      print(c,end=" ")
    print()


option=10
#Loop to display Infromations-----------
#Exit loop when the value is 0
while option != "0": 
  print("What kind of information do you need ?")
  print("1 -> For University Information")
  print("2 -> Deperntments Informations")
  print("3 -> Admission Infromation")
  print("4 -> Student Information")
  print("5 -> Libarary Information")
  print("6 -> Grading System's Information")
  print("0 -> If you dont need any Information")
  option = input("Select option: ")

  print("\n")    


#Check chosen option and call the appropriate function
  if option == "1":
    University_info()
    print("\n")
  elif option == "2":
    All_Faculty(Faculty)
    print("\n")
    print("Do you want to check out our depertments?")
    print("If YES Press-1:")
    print("If NO Press-0:")
    code=int(input("Enter the needed code----"))
    if code==1:
       get_Depertment_data() 
    else:
      print("THANK YOU FOR CHECKING IN ^-^")
    print("\n") 
  elif option =="3":
    Admission_info()
    print("\n")
    print("Do you want to appy for Admission?")
    print("If you want press-1.")
    print("If you dont press-0.")
    code=int(input("Enter 1/0----"))
    if code==1:
      Apply_for_Admission()     
    else:
      print("\n")
      print("THANK YOU FOR CHECKING IN ^-^")       
    print("\n")
  elif option =="4":
    Total_students()
    print("\n")
  elif option =="5":
    Display_Books_info()
    print("\n") 
    print("Are you intersted to visit book borrowing section?")
    print("If YES press-1")
    print("If NO press-0")
    code=int(input("Enter 1/0------"))
    if code!=0:
      Borrow_book()    
    else:
      print("\n")
      print("THANK YOU FOR CHEEKING IN ^-^") 
    print("\n")   
     
  elif option =="6":
    Grading_info()
    print("\n")
    print("-------------GRADE ADD/DELETE STEPS----------")
    print("Do you want to Add/delete any Grading system? ")
    print("For Add enter-1","-----","For Delete enter-2")
    print("If you dont want to Add/Delete Press-0 ")
    code=input("Enter 1/2/0----")  
    print("\n")  
    if code == "1":
      Add_grading()
    elif code=="2":
        delete_Grading()
    else:
      print("\n")
      print("THANK YOU FOR CHEAKING IN ^-^")
    print("\n")

  elif option == "0":
    print("^-^ THANK YOU SO MUCH FOR VISITING OUR UNIVERSITY MANAGEMENT STYSTERM ^-^")
    break
# Out:
# What kind of information do you need ?
# 1 -> For University Information
# 2 -> Deperntments Informations
# 3 -> Admission Infromation
# 4 -> Student Information
# 5 -> Libarary Information
# 6 -> Grading System's Information
# 0 -> If you dont need any Information

# %% [markdown]
# Name: Nusrat Jahan Shawon.
# ID No:2130528.
# Subject: CSCL-101.
# Section:9
